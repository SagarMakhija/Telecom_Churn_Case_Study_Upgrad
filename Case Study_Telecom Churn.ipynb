# %% [markdown]
# ## Problem Statement
#
# Predict whether the customer will churn or not in Churn Phase while analysis the Data of customer in Action Phase. Churn to be predicted of High Value Customer as 80% of the revenue is contributed by these 20% of total customer.
#
# High value Customers are those whose recharge value is greater then 70% of average recharge value
# Customer data is of period June to Sept, where sept period is of churn phase customers

# %%
## Importing the Libraries

import numpy as np
import pandas as pd

from IPython.core.display import display, HTML
display(HTML("<style>.container {width:100% !important;}</style>"))

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
# Out:
# <style>.container {width:100% !important;}</style>

# %% [markdown]
# ## Inspecting the Data

# %%
## Read the Data

Data = pd.read_csv("telecom_churn_data.csv")
Data.head()
# Out:
#    mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 0     7000842753        109             0.0             0.0             0.0
# 1     7001865778        109             0.0             0.0             0.0
# 2     7001625959        109             0.0             0.0             0.0
# 3     7001204172        109             0.0             0.0             0.0
# 4     7000142493        109             0.0             0.0             0.0
#
#   last_date_of_month_6 last_date_of_month_7 last_date_of_month_8  \
# 0            6/30/2014            7/31/2014            8/31/2014
# 1            6/30/2014            7/31/2014            8/31/2014
# 2            6/30/2014            7/31/2014            8/31/2014
# 3            6/30/2014            7/31/2014            8/31/2014
# 4            6/30/2014            7/31/2014            8/31/2014
#
#   last_date_of_month_9   arpu_6  ...  sachet_3g_9  fb_user_6  fb_user_7  \
# 0            9/30/2014  197.385  ...            0        1.0        1.0
# 1            9/30/2014   34.047  ...            0        NaN        1.0
# 2            9/30/2014  167.690  ...            0        NaN        NaN
# 3            9/30/2014  221.338  ...            0        NaN        NaN
# 4            9/30/2014  261.636  ...            0        0.0        NaN
#
#    fb_user_8  fb_user_9   aon  aug_vbc_3g  jul_vbc_3g  jun_vbc_3g  sep_vbc_3g
# 0        1.0        NaN   968        30.4         0.0      101.20        3.58
# 1        1.0        NaN  1006         0.0         0.0        0.00        0.00
# 2        NaN        1.0  1103         0.0         0.0        4.17        0.00
# 3        NaN        NaN  2491         0.0         0.0        0.00        0.00
# 4        NaN        NaN  1526         0.0         0.0        0.00        0.00
#
# [5 rows x 226 columns]

# %%
## Data Summary

Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99999 entries, 0 to 99998
# Columns: 226 entries, mobile_number to sep_vbc_3g
# dtypes: float64(179), int64(35), object(12)
# memory usage: 172.4+ MB

# %%
## Shape of the Data
Data.shape
# Out:
# (99999, 226)

# %%
## Columns of the Data

Data.columns
# Out:
# Index(['mobile_number', 'circle_id', 'loc_og_t2o_mou', 'std_og_t2o_mou',
#        'loc_ic_t2o_mou', 'last_date_of_month_6', 'last_date_of_month_7',
#        'last_date_of_month_8', 'last_date_of_month_9', 'arpu_6',
#        ...
#        'sachet_3g_9', 'fb_user_6', 'fb_user_7', 'fb_user_8', 'fb_user_9',
#        'aon', 'aug_vbc_3g', 'jul_vbc_3g', 'jun_vbc_3g', 'sep_vbc_3g'],
#       dtype='object', length=226)

# %%
#Check the metadata with verbose( Show all the column names)
Data.info(verbose=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99999 entries, 0 to 99998
# Data columns (total 226 columns):
#  #    Column                    Dtype
# ---   ------                    -----
#  0    mobile_number             int64
#  1    circle_id                 int64
#  2    loc_og_t2o_mou            float64
#  3    std_og_t2o_mou            float64
#  4    loc_ic_t2o_mou            float64
#  5    last_date_of_month_6      object
#  6    last_date_of_month_7      object
#  7    last_date_of_month_8      object
#  8    last_date_of_month_9      object
#  9    arpu_6                    float64
#  10   arpu_7                    float64
#  11   arpu_8                    float64
#  12   arpu_9                    float64
#  13   onnet_mou_6               float64
#  14   onnet_mou_7               float64
#  15   onnet_mou_8               float64
#  16   onnet_mou_9               float64
#  17   offnet_mou_6              float64
#  18   offnet_mou_7              float64
#  19   offnet_mou_8              float64
#  20   offnet_mou_9              float64
#  21   roam_ic_mou_6             float64
#  22   roam_ic_mou_7             float64
#  23   roam_ic_mou_8             float64
#  24   roam_ic_mou_9             float64
#  25   roam_og_mou_6             float64
#  26   roam_og_mou_7             float64
#  27   roam_og_mou_8             float64
#  28   roam_og_mou_9             float64
#  29   loc_og_t2t_mou_6          float64
#  30   loc_og_t2t_mou_7          float64
#  31   loc_og_t2t_mou_8          float64
#  32   loc_og_t2t_mou_9          float64
#  33   loc_og_t2m_mou_6          float64
#  34   loc_og_t2m_mou_7          float64
#  35   loc_og_t2m_mou_8          float64
#  36   loc_og_t2m_mou_9          float64
#  37   loc_og_t2f_mou_6          float64
#  38   loc_og_t2f_mou_7          float64
#  39   loc_og_t2f_mou_8          float64
#  40   loc_og_t2f_mou_9          float64
#  41   loc_og_t2c_mou_6          float64
#  42   loc_og_t2c_mou_7          float64
#  43   loc_og_t2c_mou_8          float64
#  44   loc_og_t2c_mou_9          float64
#  45   loc_og_mou_6              float64
#  46   loc_og_mou_7              float64
#  47   loc_og_mou_8              float64
#  48   loc_og_mou_9              float64
#  49   std_og_t2t_mou_6          float64
#  50   std_og_t2t_mou_7          float64
#  51   std_og_t2t_mou_8          float64
#  52   std_og_t2t_mou_9          float64
#  53   std_og_t2m_mou_6          float64
#  54   std_og_t2m_mou_7          float64
#  55   std_og_t2m_mou_8          float64
#  56   std_og_t2m_mou_9          float64
#  57   std_og_t2f_mou_6          float64
#  58   std_og_t2f_mou_7          float64
#  59   std_og_t2f_mou_8          float64
#  60   std_og_t2f_mou_9          float64
#  61   std_og_t2c_mou_6          float64
#  62   std_og_t2c_mou_7          float64
#  63   std_og_t2c_mou_8          float64
#  64   std_og_t2c_mou_9          float64
#  65   std_og_mou_6              float64
#  66   std_og_mou_7              float64
#  67   std_og_mou_8              float64
#  68   std_og_mou_9              float64
#  69   isd_og_mou_6              float64
#  70   isd_og_mou_7              float64
#  71   isd_og_mou_8              float64
#  72   isd_og_mou_9              float64
#  73   spl_og_mou_6              float64
#  74   spl_og_mou_7              float64
#  75   spl_og_mou_8              float64
#  76   spl_og_mou_9              float64
#  77   og_others_6               float64
#  78   og_others_7               float64
#  79   og_others_8               float64
#  80   og_others_9               float64
#  81   total_og_mou_6            float64
#  82   total_og_mou_7            float64
#  83   total_og_mou_8            float64
#  84   total_og_mou_9            float64
#  85   loc_ic_t2t_mou_6          float64
#  86   loc_ic_t2t_mou_7          float64
#  87   loc_ic_t2t_mou_8          float64
#  88   loc_ic_t2t_mou_9          float64
#  89   loc_ic_t2m_mou_6          float64
#  90   loc_ic_t2m_mou_7          float64
#  91   loc_ic_t2m_mou_8          float64
#  92   loc_ic_t2m_mou_9          float64
#  93   loc_ic_t2f_mou_6          float64
#  94   loc_ic_t2f_mou_7          float64
#  95   loc_ic_t2f_mou_8          float64
#  96   loc_ic_t2f_mou_9          float64
#  97   loc_ic_mou_6              float64
#  98   loc_ic_mou_7              float64
#  99   loc_ic_mou_8              float64
#  100  loc_ic_mou_9              float64
#  101  std_ic_t2t_mou_6          float64
#  102  std_ic_t2t_mou_7          float64
#  103  std_ic_t2t_mou_8          float64
#  104  std_ic_t2t_mou_9          float64
#  105  std_ic_t2m_mou_6          float64
#  106  std_ic_t2m_mou_7          float64
#  107  std_ic_t2m_mou_8          float64
#  108  std_ic_t2m_mou_9          float64
#  109  std_ic_t2f_mou_6          float64
#  110  std_ic_t2f_mou_7          float64
#  111  std_ic_t2f_mou_8          float64
#  112  std_ic_t2f_mou_9          float64
#  113  std_ic_t2o_mou_6          float64
#  114  std_ic_t2o_mou_7          float64
#  115  std_ic_t2o_mou_8          float64
#  116  std_ic_t2o_mou_9          float64
#  117  std_ic_mou_6              float64
#  118  std_ic_mou_7              float64
#  119  std_ic_mou_8              float64
#  120  std_ic_mou_9              float64
#  121  total_ic_mou_6            float64
#  122  total_ic_mou_7            float64
#  123  total_ic_mou_8            float64
#  124  total_ic_mou_9            float64
#  125  spl_ic_mou_6              float64
#  126  spl_ic_mou_7              float64
#  127  spl_ic_mou_8              float64
#  128  spl_ic_mou_9              float64
#  129  isd_ic_mou_6              float64
#  130  isd_ic_mou_7              float64
#  131  isd_ic_mou_8              float64
#  132  isd_ic_mou_9              float64
#  133  ic_others_6               float64
#  134  ic_others_7               float64
#  135  ic_others_8               float64
#  136  ic_others_9               float64
#  137  total_rech_num_6          int64
#  138  total_rech_num_7          int64
#  139  total_rech_num_8          int64
#  140  total_rech_num_9          int64
#  141  total_rech_amt_6          int64
#  142  total_rech_amt_7          int64
#  143  total_rech_amt_8          int64
#  144  total_rech_amt_9          int64
#  145  max_rech_amt_6            int64
#  146  max_rech_amt_7            int64
#  147  max_rech_amt_8            int64
#  148  max_rech_amt_9            int64
#  149  date_of_last_rech_6       object
#  150  date_of_last_rech_7       object
#  151  date_of_last_rech_8       object
#  152  date_of_last_rech_9       object
#  153  last_day_rch_amt_6        int64
#  154  last_day_rch_amt_7        int64
#  155  last_day_rch_amt_8        int64
#  156  last_day_rch_amt_9        int64
#  157  date_of_last_rech_data_6  object
#  158  date_of_last_rech_data_7  object
#  159  date_of_last_rech_data_8  object
#  160  date_of_last_rech_data_9  object
#  161  total_rech_data_6         float64
#  162  total_rech_data_7         float64
#  163  total_rech_data_8         float64
#  164  total_rech_data_9         float64
#  165  max_rech_data_6           float64
#  166  max_rech_data_7           float64
#  167  max_rech_data_8           float64
#  168  max_rech_data_9           float64
#  169  count_rech_2g_6           float64
#  170  count_rech_2g_7           float64
#  171  count_rech_2g_8           float64
#  172  count_rech_2g_9           float64
#  173  count_rech_3g_6           float64
#  174  count_rech_3g_7           float64
#  175  count_rech_3g_8           float64
#  176  count_rech_3g_9           float64
#  177  av_rech_amt_data_6        float64
#  178  av_rech_amt_data_7        float64
#  179  av_rech_amt_data_8        float64
#  180  av_rech_amt_data_9        float64
#  181  vol_2g_mb_6               float64
#  182  vol_2g_mb_7               float64
#  183  vol_2g_mb_8               float64
#  184  vol_2g_mb_9               float64
#  185  vol_3g_mb_6               float64
#  186  vol_3g_mb_7               float64
#  187  vol_3g_mb_8               float64
#  188  vol_3g_mb_9               float64
#  189  arpu_3g_6                 float64
#  190  arpu_3g_7                 float64
#  191  arpu_3g_8                 float64
#  192  arpu_3g_9                 float64
#  193  arpu_2g_6                 float64
#  194  arpu_2g_7                 float64
#  195  arpu_2g_8                 float64
#  196  arpu_2g_9                 float64
#  197  night_pck_user_6          float64
#  198  night_pck_user_7          float64
#  199  night_pck_user_8          float64
#  200  night_pck_user_9          float64
#  201  monthly_2g_6              int64
#  202  monthly_2g_7              int64
#  203  monthly_2g_8              int64
#  204  monthly_2g_9              int64
#  205  sachet_2g_6               int64
#  206  sachet_2g_7               int64
#  207  sachet_2g_8               int64
#  208  sachet_2g_9               int64
#  209  monthly_3g_6              int64
#  210  monthly_3g_7              int64
#  211  monthly_3g_8              int64
#  212  monthly_3g_9              int64
#  213  sachet_3g_6               int64
#  214  sachet_3g_7               int64
#  215  sachet_3g_8               int64
#  216  sachet_3g_9               int64
#  217  fb_user_6                 float64
#  218  fb_user_7                 float64
#  219  fb_user_8                 float64
#  220  fb_user_9                 float64
#  221  aon                       int64
#  222  aug_vbc_3g                float64
#  223  jul_vbc_3g                float64
#  224  jun_vbc_3g                float64
#  225  sep_vbc_3g                float64
# dtypes: float64(179), int64(35), object(12)
# memory usage: 172.4+ MB

# %% [markdown]
# Dataset contains 99999 no of rows.
#
# 226 no of columns.
#
# Number of Float data type - 179
#
# Number of int datatype - 35
#
# Number of object datatype- 12

# %%
# Segregate Categorcial, ID and Numeric columns for ease of analysis

#Categorcial columns separation : categorical columns are only date here
date_columns = [col for col in Data.columns if Data[col].dtype =="object"]    
print(f"Total Categorical columns:{len(date_columns)}")

#ID columns separation
id_columns = ["mobile_number","circle_id"]  # total ID columns are 2 
print(f"Total numeric columns:{len(id_columns)}")

#Numeric columns separation
numeric_columns = [ col for col in Data.columns if col not in date_columns + id_columns]    
print(f"Total numeric columns:{len(numeric_columns)}")
# Out:
# Total Categorical columns:12
# Total numeric columns:2
# Total numeric columns:212

# %% [markdown]
# ## Data Preparation

# %%
### High Value Customers

Data["Avg_Rech"]=(Data["total_rech_amt_6"]+Data["total_rech_amt_7"])/2
Data["Good_Phase_Rech"] = np.percentile(Data["Avg_Rech"],70)
Data["HV_Customer"] = Data["total_rech_amt_8"]>=Data["Good_Phase_Rech"]
HV_Data = Data[Data["HV_Customer"]==True]
HV_Data.shape
# Out:
# (30957, 229)

# %%
## Tagging the Churn Customer

C1= HV_Data["total_og_mou_9"]==0
C2= HV_Data["total_ic_mou_9"]==0
C3= HV_Data["vol_2g_mb_9"]==0
C4= HV_Data["vol_3g_mb_9"]==0

HV_Data["Churn"]= np.where((C1|C2)&(C3|C4),1,0)
HV_Data.Churn.value_counts()
# Out:
# 0    29686
# 1     1271
# Name: Churn, dtype: int64

# %%
## Dropping the Churn Phase Columns

Churn_Columns = HV_Data.columns[HV_Data.columns.astype('str').str.contains("_9")==True]
HV_Data=HV_Data.drop(labels=Churn_Columns,axis=1)
HV_Data.shape
# Out:
# (30957, 176)

# %%
## Missing Values

Null_count = pd.DataFrame(HV_Data[HV_Data.columns[HV_Data.isnull().any()]].isnull().sum() * 100 / HV_Data.shape[0])

# %%
Null_count
# Out:
#                               0
# loc_og_t2o_mou         0.284265
# std_og_t2o_mou         0.284265
# loc_ic_t2o_mou         0.284265
# last_date_of_month_7   0.006461
# onnet_mou_6            3.327196
# ...                         ...
# night_pck_user_7      64.147043
# night_pck_user_8      58.019188
# fb_user_6             66.857254
# fb_user_7             64.147043
# fb_user_8             58.019188
#
# [123 rows x 1 columns]

# %%
Null_count[Null_count[0]>50].index
# Out:
# Index(['date_of_last_rech_data_6', 'date_of_last_rech_data_7',
#        'date_of_last_rech_data_8', 'total_rech_data_6', 'total_rech_data_7',
#        'total_rech_data_8', 'max_rech_data_6', 'max_rech_data_7',
#        'max_rech_data_8', 'count_rech_2g_6', 'count_rech_2g_7',
#        'count_rech_2g_8', 'count_rech_3g_6', 'count_rech_3g_7',
#        'count_rech_3g_8', 'av_rech_amt_data_6', 'av_rech_amt_data_7',
#        'av_rech_amt_data_8', 'arpu_3g_6', 'arpu_3g_7', 'arpu_3g_8',
#        'arpu_2g_6', 'arpu_2g_7', 'arpu_2g_8', 'night_pck_user_6',
#        'night_pck_user_7', 'night_pck_user_8', 'fb_user_6', 'fb_user_7',
#        'fb_user_8'],
#       dtype='object')

# %%
HV_Data["fb_user_8"].value_counts()
# Out:
# 1.0    11294
# 0.0     1702
# Name: fb_user_8, dtype: int64

# %%
HV_Data["fb_user_8"].isnull().sum()
# Out:
# 17961

# %%
HV_Data=HV_Data.drop(columns=Null_count[Null_count[0]>50].index)

# %%
A=HV_Data[HV_Data.columns[HV_Data.isnull().any()]].isnull().sum() * 100 / HV_Data.shape[0]

# %%
## Impute Missing Values

A.sort_values()
# Out:
# last_date_of_month_7    0.006461
# loc_og_t2o_mou          0.284265
# std_og_t2o_mou          0.284265
# loc_ic_t2o_mou          0.284265
# loc_ic_t2t_mou_8        0.445780
#                           ...
# loc_ic_mou_6            3.327196
# loc_og_t2t_mou_6        3.327196
# std_ic_t2t_mou_6        3.327196
# loc_og_t2f_mou_6        3.327196
# isd_og_mou_6            3.327196
# Length: 93, dtype: float64

# %%
HV_Data = HV_Data.dropna(axis=0,how='any')

# %%
## Check Continuous and Categorical Variables

for i in HV_Data.columns:
    A = HV_Data[i].value_counts()
    print(i,"Unique Values =",A)
# Out:
# mobile_number Unique Values = 7001204172    1
# 7001444668    1
# 7001688602    1
# 7000280683    1
# 7000542480    1
#              ..
# 7001789440    1
# 7001691543    1
# 7000175260    1
# 7001427073    1
# 7000498689    1
# Name: mobile_number, Length: 29487, dtype: int64
# circle_id Unique Values = 109    29487
# Name: circle_id, dtype: int64
# loc_og_t2o_mou Unique Values = 0.0    29487
# Name: loc_og_t2o_mou, dtype: int64
# std_og_t2o_mou Unique Values = 0.0    29487
# Name: std_og_t2o_mou, dtype: int64
# loc_ic_t2o_mou Unique Values = 0.0    29487
# Name: loc_ic_t2o_mou, dtype: int64
# last_date_of_month_6 Unique Values = 6/30/2014    29487
# Name: last_date_of_month_6, dtype: int64
# last_date_of_month_7 Unique Values = 7/31/2014    29487
# Name: last_date_of_month_7, dtype: int64
# last_date_of_month_8 Unique Values = 8/31/2014    29487
# Name: last_date_of_month_8, dtype: int64
# arpu_6 Unique Values = 0.000       328
# 3.000        11
# 1.000        11
# 0.750        11
# 1.500        10
#            ...
# 542.369       1
# 679.755       1
# 29.140        1
# 1168.764      1
# 322.991       1
# Name: arpu_6, Length: 28454, dtype: int64
# arpu_7 Unique Values = 0.000      160
# 0.010        5
# 1.000        4
# 0.040        4
# 0.100        4
#           ...
# 103.763      1
# 391.510      1
# 202.864      1
# 535.471      1
# 303.386      1
# Name: arpu_7, Length: 28775, dtype: int64
# arpu_8 Unique Values = 577.830     3
# 311.908     3
# 371.426     3
# 478.100     3
# 427.582     3
#            ..
# 1404.254    1
# 465.111     1
# 466.789     1
# 1028.653    1
# 606.817     1
# Name: arpu_8, Length: 28878, dtype: int64
# onnet_mou_6 Unique Values = 0.00       1427
# 0.26         17
# 0.98         16
# 0.31         16
# 1.01         14
#            ...
# 2643.23       1
# 801.43        1
# 850.51        1
# 269.96        1
# 196.99        1
# Name: onnet_mou_6, Length: 16867, dtype: int64
# onnet_mou_7 Unique Values = 0.00       954
# 20.06       12
# 1.68        11
# 0.01        11
# 7.21        11
#           ...
# 238.89       1
# 1313.56      1
# 89.89        1
# 377.26       1
# 29.04        1
# Name: onnet_mou_7, Length: 17865, dtype: int64
# onnet_mou_8 Unique Values = 0.00      511
# 2.23       10
# 17.43      10
# 53.56      10
# 8.21       10
#          ...
# 727.64      1
# 323.09      1
# 415.56      1
# 137.89      1
# 63.91       1
# Name: onnet_mou_8, Length: 18764, dtype: int64
# offnet_mou_6 Unique Values = 0.00      661
# 0.16       10
# 1.01        8
# 0.86        8
# 0.56        8
#          ...
# 29.54       1
# 88.16       1
# 620.04      1
# 139.36      1
# 175.88      1
# Name: offnet_mou_6, Length: 20956, dtype: int64
# offnet_mou_7 Unique Values = 0.00      419
# 95.38       7
# 0.78        7
# 62.43       6
# 32.74       6
#          ...
# 118.16      1
# 6.21        1
# 136.76      1
# 2.74        1
# 277.01      1
# Name: offnet_mou_7, Length: 21649, dtype: int64
# offnet_mou_8 Unique Values = 0.00      153
# 279.28      7
# 359.39      6
# 296.26      6
# 184.66      6
#          ...
# 218.91      1
# 111.19      1
# 131.99      1
# 769.28      1
# 61.44       1
# Name: offnet_mou_8, Length: 22432, dtype: int64
# roam_ic_mou_6 Unique Values = 0.00      22065
# 1.01         27
# 0.35         17
# 1.15         14
# 3.18         14
#           ...
# 29.84         1
# 0.59          1
# 371.91        1
# 77.23         1
# 45.19         1
# Name: roam_ic_mou_6, Length: 4121, dtype: int64
# roam_ic_mou_7 Unique Values = 0.00      24363
# 0.20         14
# 1.01         12
# 3.28         11
# 1.40         11
#           ...
# 260.33        1
# 17.59         1
# 66.13         1
# 3.85          1
# 104.94        1
# Name: roam_ic_mou_7, Length: 3273, dtype: int64
# roam_ic_mou_8 Unique Values = 0.00      24199
# 2.28         10
# 1.91         10
# 1.18         10
# 1.41          9
#           ...
# 30.63         1
# 58.46         1
# 38.76         1
# 139.96        1
# 24.31         1
# Name: roam_ic_mou_8, Length: 3582, dtype: int64
# roam_og_mou_6 Unique Values = 0.00      22030
# 0.21         25
# 1.01         17
# 0.28         13
# 0.60         13
#           ...
# 68.44         1
# 277.04        1
# 15.05         1
# 138.74        1
# 97.71         1
# Name: roam_og_mou_6, Length: 4953, dtype: int64
# roam_og_mou_7 Unique Values = 0.00      24417
# 0.11          9
# 0.21          8
# 0.48          8
# 2.58          7
#           ...
# 300.09        1
# 128.48        1
# 25.68         1
# 123.88        1
# 195.74        1
# Name: roam_og_mou_7, Length: 3814, dtype: int64
# roam_og_mou_8 Unique Values = 0.00      24161
# 0.55          7
# 2.01          7
# 3.16          6
# 2.38          6
#           ...
# 6.55          1
# 92.38         1
# 16.40         1
# 4.19          1
# 386.29        1
# Name: roam_og_mou_8, Length: 4142, dtype: int64
# loc_og_t2t_mou_6 Unique Values = 0.00      3411
# 0.26        26
# 0.33        25
# 1.01        25
# 2.91        24
#           ...
# 201.54       1
# 320.43       1
# 78.11        1
# 226.46       1
# 170.28       1
# Name: loc_og_t2t_mou_6, Length: 10370, dtype: int64
# loc_og_t2t_mou_7 Unique Values = 0.00      2243
# 2.53        27
# 0.48        21
# 0.43        21
# 0.28        21
#           ...
# 841.76       1
# 310.13       1
# 378.31       1
# 148.81       1
# 335.38       1
# Name: loc_og_t2t_mou_7, Length: 10693, dtype: int64
# loc_og_t2t_mou_8 Unique Values = 0.00      1496
# 3.24        24
# 0.36        24
# 0.33        22
# 0.50        22
#           ...
# 170.13       1
# 96.61        1
# 94.79        1
# 144.94       1
# 406.34       1
# Name: loc_og_t2t_mou_8, Length: 11051, dtype: int64
# loc_og_t2m_mou_6 Unique Values = 0.00      2234
# 0.86        14
# 1.98        13
# 0.61        12
# 1.71        12
#           ...
# 39.91        1
# 7.39         1
# 230.81       1
# 266.89       1
# 52.21        1
# Name: loc_og_t2m_mou_6, Length: 15496, dtype: int64
# loc_og_t2m_mou_7 Unique Values = 0.00      1263
# 8.96        12
# 1.83        12
# 0.23        11
# 2.03        10
#           ...
# 788.34       1
# 95.94        1
# 241.28       1
# 360.63       1
# 43.06        1
# Name: loc_og_t2m_mou_7, Length: 16089, dtype: int64
# loc_og_t2m_mou_8 Unique Values = 0.00      635
# 9.96       11
# 12.16      10
# 1.03       10
# 4.24       10
#          ...
# 202.14      1
# 451.88      1
# 665.74      1
# 162.28      1
# 115.69      1
# Name: loc_og_t2m_mou_8, Length: 16831, dtype: int64
# loc_og_t2f_mou_6 Unique Values = 0.00      14627
# 0.38         66
# 0.51         65
# 0.26         64
# 0.28         63
#           ...
# 48.73         1
# 98.78         1
# 17.73         1
# 148.69        1
# 19.58         1
# Name: loc_og_t2f_mou_6, Length: 3116, dtype: int64
# loc_og_t2f_mou_7 Unique Values = 0.00      13717
# 0.46         77
# 0.61         71
# 0.40         68
# 0.28         68
#           ...
# 115.06        1
# 61.83         1
# 81.83         1
# 16.44         1
# 120.23        1
# Name: loc_og_t2f_mou_7, Length: 3181, dtype: int64
# loc_og_t2f_mou_8 Unique Values = 0.00      13232
# 0.41         73
# 0.45         68
# 0.33         68
# 0.56         65
#           ...
# 49.91         1
# 37.73         1
# 124.46        1
# 25.03         1
# 173.91        1
# Name: loc_og_t2f_mou_8, Length: 3192, dtype: int64
# loc_og_t2c_mou_6 Unique Values = 0.00     22952
# 0.01        72
# 0.03        62
# 0.08        53
# 0.11        47
#          ...
# 34.24        1
# 16.20        1
# 12.90        1
# 70.06        1
# 22.23        1
# Name: loc_og_t2c_mou_6, Length: 1533, dtype: int64
# loc_og_t2c_mou_7 Unique Values = 0.00     22109
# 0.01        67
# 0.08        66
# 0.06        65
# 0.11        58
#          ...
# 12.11        1
# 27.41        1
# 17.64        1
# 29.06        1
# 23.10        1
# Name: loc_og_t2c_mou_7, Length: 1689, dtype: int64
# loc_og_t2c_mou_8 Unique Values = 0.00     20880
# 0.13       105
# 0.01       101
# 0.10        70
# 0.26        68
#          ...
# 17.74        1
# 21.66        1
# 39.44        1
# 28.68        1
# 56.96        1
# Name: loc_og_t2c_mou_8, Length: 1871, dtype: int64
# loc_og_mou_6 Unique Values = 0.00       1990
# 0.61         11
# 1.11         10
# 1.28         10
# 5.51         10
#            ...
# 1273.36       1
# 414.68        1
# 769.34        1
# 960.18        1
# 124.74        1
# Name: loc_og_mou_6, Length: 18188, dtype: int64
# loc_og_mou_7 Unique Values = 0.00       1110
# 2.48          9
# 6.83          9
# 11.99         8
# 37.71         8
#            ...
# 642.81        1
# 24.48         1
# 1708.98       1
# 334.31        1
# 295.26        1
# Name: loc_og_mou_7, Length: 19038, dtype: int64
# loc_og_mou_8 Unique Values = 0.00      522
# 1.03        9
# 13.11       8
# 50.78       8
# 14.54       8
#          ...
# 117.89      1
# 241.64      1
# 20.79       1
# 897.66      1
# 150.59      1
# Name: loc_og_mou_8, Length: 19731, dtype: int64
# std_og_t2t_mou_6 Unique Values = 0.00       12065
# 0.43          23
# 1.06          22
# 0.33          21
# 0.20          21
#            ...
# 5.34           1
# 1308.41        1
# 202.73         1
# 158.71         1
# 29.61          1
# Name: std_og_t2t_mou_6, Length: 11194, dtype: int64
# std_og_t2t_mou_7 Unique Values = 0.00      11125
# 0.33         29
# 0.61         24
# 0.36         22
# 0.80         21
#           ...
# 143.49        1
# 75.93         1
# 217.36        1
# 386.11        1
# 27.98         1
# Name: std_og_t2t_mou_7, Length: 12171, dtype: int64
# std_og_t2t_mou_8 Unique Values = 0.00      10431
# 0.18         24
# 0.68         22
# 0.56         21
# 1.76         21
#           ...
# 84.79         1
# 264.61        1
# 234.56        1
# 223.03        1
# 237.71        1
# Name: std_og_t2t_mou_8, Length: 12811, dtype: int64
# std_og_t2m_mou_6 Unique Values = 0.00      7572
# 0.56        31
# 0.46        29
# 0.38        27
# 0.66        27
#           ...
# 263.84       1
# 405.19       1
# 83.06        1
# 110.43       1
# 38.04        1
# Name: std_og_t2m_mou_6, Length: 12573, dtype: int64
# std_og_t2m_mou_7 Unique Values = 0.00      6779
# 0.31        29
# 0.33        28
# 0.35        26
# 0.50        26
#           ...
# 111.91       1
# 977.24       1
# 361.66       1
# 195.39       1
# 128.23       1
# Name: std_og_t2m_mou_7, Length: 13579, dtype: int64
# std_og_t2m_mou_8 Unique Values = 0.00      5928
# 0.36        31
# 0.73        28
# 0.38        28
# 0.33        26
#           ...
# 40.68        1
# 248.21       1
# 104.84       1
# 416.36       1
# 120.29       1
# Name: std_og_t2m_mou_8, Length: 14444, dtype: int64
# std_og_t2f_mou_6 Unique Values = 0.00      24830
# 0.26         33
# 0.41         29
# 0.40         28
# 0.28         27
#           ...
# 11.09         1
# 230.99        1
# 75.16         1
# 32.60         1
# 9.59          1
# Name: std_og_t2f_mou_6, Length: 1701, dtype: int64
# std_og_t2f_mou_7 Unique Values = 0.00     24843
# 0.25        30
# 0.45        29
# 0.43        28
# 0.48        26
#          ...
# 9.31         1
# 45.59        1
# 19.61        1
# 40.19        1
# 29.48        1
# Name: std_og_t2f_mou_7, Length: 1649, dtype: int64
# std_og_t2f_mou_8 Unique Values = 0.00     24603
# 0.35        29
# 0.36        27
# 0.55        26
# 0.45        26
#          ...
# 18.44        1
# 40.69        1
# 20.36        1
# 16.38        1
# 21.31        1
# Name: std_og_t2f_mou_8, Length: 1695, dtype: int64
# std_og_t2c_mou_6 Unique Values = 0.0    29487
# Name: std_og_t2c_mou_6, dtype: int64
# std_og_t2c_mou_7 Unique Values = 0.0    29487
# Name: std_og_t2c_mou_7, dtype: int64
# std_og_t2c_mou_8 Unique Values = 0.0    29487
# Name: std_og_t2c_mou_8, dtype: int64
# std_og_mou_6 Unique Values = 0.00      5703
# 0.56        26
# 0.60        26
# 0.46        24
# 0.58        24
#           ...
# 38.88        1
# 943.94       1
# 63.03        1
# 621.06       1
# 983.03       1
# Name: std_og_mou_6, Length: 16153, dtype: int64
# std_og_mou_7 Unique Values = 0.00      5011
# 0.50        30
# 0.20        25
# 0.31        25
# 0.33        25
#           ...
# 455.44       1
# 49.36        1
# 853.74       1
# 570.11       1
# 156.21       1
# Name: std_og_mou_7, Length: 17277, dtype: int64
# std_og_mou_8 Unique Values = 0.00       4197
# 0.36         27
# 0.45         25
# 0.68         24
# 0.56         23
#            ...
# 682.09        1
# 824.56        1
# 1013.03       1
# 130.88        1
# 120.29        1
# Name: std_og_mou_8, Length: 18190, dtype: int64
# isd_og_mou_6 Unique Values = 0.00      27237
# 1.01         56
# 0.01         42
# 0.03         35
# 0.06         29
#           ...
# 8.13          1
# 3.70          1
# 74.21         1
# 150.99        1
# 2.68          1
# Name: isd_og_mou_6, Length: 929, dtype: int64
# isd_og_mou_7 Unique Values = 0.00     27280
# 0.01        56
# 1.01        36
# 0.03        34
# 0.05        32
#          ...
# 21.13        1
# 3.33         1
# 13.06        1
# 36.89        1
# 5.28         1
# Name: isd_og_mou_7, Length: 991, dtype: int64
# isd_og_mou_8 Unique Values = 0.00      27256
# 0.01         42
# 1.01         40
# 0.03         36
# 0.06         27
#           ...
# 57.43         1
# 148.11        1
# 103.64        1
# 53.64         1
# 10.84         1
# Name: isd_og_mou_8, Length: 980, dtype: int64
# spl_og_mou_6 Unique Values = 0.00      15227
# 0.01         96
# 0.21         87
# 0.03         76
# 0.11         70
#           ...
# 38.39         1
# 53.28         1
# 43.98         1
# 110.39        1
# 16.66         1
# Name: spl_og_mou_6, Length: 2800, dtype: int64
# spl_og_mou_7 Unique Values = 0.00     13220
# 0.01        95
# 0.08        85
# 0.03        78
# 0.06        64
#          ...
# 29.31        1
# 29.59        1
# 38.06        1
# 32.23        1
# 14.80        1
# Name: spl_og_mou_7, Length: 3200, dtype: int64
# spl_og_mou_8 Unique Values = 0.00      11870
# 0.01        111
# 0.08         82
# 0.13         81
# 0.03         75
#           ...
# 70.69         1
# 74.71         1
# 20.24         1
# 11.25         1
# 478.38        1
# Name: spl_og_mou_8, Length: 3437, dtype: int64
# og_others_6 Unique Values = 0.00     23563
# 0.21       134
# 0.65        54
# 0.43        52
# 0.76        46
#          ...
# 9.74         1
# 31.19        1
# 18.04        1
# 7.73         1
# 10.76        1
# Name: og_others_6, Length: 787, dtype: int64
# og_others_7 Unique Values = 0.00     29340
# 0.03         5
# 1.61         4
# 0.38         4
# 0.05         3
#          ...
# 98.53        1
# 3.41         1
# 8.43         1
# 0.78         1
# 0.13         1
# Name: og_others_7, Length: 105, dtype: int64
# og_others_8 Unique Values = 0.00     29304
# 0.16         5
# 2.26         5
# 1.03         4
# 0.40         4
#          ...
# 6.70         1
# 0.60         1
# 2.86         1
# 0.66         1
# 24.24        1
# Name: og_others_8, Length: 135, dtype: int64
# total_og_mou_6 Unique Values = 0.00       1640
# 0.21         15
# 0.41          6
# 0.20          6
# 512.89        5
#            ...
# 1723.36       1
# 196.73        1
# 565.53        1
# 461.48        1
# 375.78        1
# Name: total_og_mou_6, Length: 23159, dtype: int64
# total_og_mou_7 Unique Values = 0.00       880
# 0.21         6
# 148.28       5
# 277.73       5
# 120.64       5
#           ...
# 334.53       1
# 8.30         1
# 2518.71      1
# 141.68       1
# 57.14        1
# Name: total_og_mou_7, Length: 24248, dtype: int64
# total_og_mou_8 Unique Values = 0.00      394
# 386.03      5
# 930.34      5
# 158.26      5
# 132.94      5
#          ...
# 687.38      1
# 685.71      1
# 533.11      1
# 421.46      1
# 250.79      1
# Name: total_og_mou_8, Length: 24764, dtype: int64
# loc_ic_t2t_mou_6 Unique Values = 0.00      2896
# 0.48        26
# 0.63        26
# 0.31        25
# 0.58        25
#           ...
# 500.99       1
# 437.28       1
# 106.43       1
# 170.06       1
# 232.24       1
# Name: loc_ic_t2t_mou_6, Length: 9363, dtype: int64
# loc_ic_t2t_mou_7 Unique Values = 0.00      1840
# 0.78        30
# 0.91        27
# 0.66        26
# 0.31        24
#           ...
# 69.28        1
# 250.53       1
# 220.78       1
# 84.13        1
# 264.44       1
# Name: loc_ic_t2t_mou_7, Length: 9649, dtype: int64
# loc_ic_t2t_mou_8 Unique Values = 0.00      1254
# 0.36        23
# 0.50        22
# 3.36        20
# 0.48        20
#           ...
# 333.94       1
# 713.54       1
# 102.04       1
# 106.89       1
# 303.61       1
# Name: loc_ic_t2t_mou_8, Length: 9880, dtype: int64
# loc_ic_t2m_mou_6 Unique Values = 0.00      1815
# 3.36        11
# 19.79       11
# 0.46        10
# 0.83        10
#           ...
# 159.54       1
# 20.01        1
# 482.81       1
# 285.78       1
# 245.31       1
# Name: loc_ic_t2m_mou_6, Length: 15172, dtype: int64
# loc_ic_t2m_mou_7 Unique Values = 0.00       920
# 14.31       10
# 49.79        9
# 63.98        9
# 15.01        9
#           ...
# 281.63       1
# 176.46       1
# 1323.41      1
# 131.94       1
# 256.46       1
# Name: loc_ic_t2m_mou_7, Length: 15647, dtype: int64
# loc_ic_t2m_mou_8 Unique Values = 0.00       440
# 0.78        10
# 31.01       10
# 4.33         9
# 62.59        9
#           ...
# 174.36       1
# 479.94       1
# 62.76        1
# 53.38        1
# 1122.83      1
# Name: loc_ic_t2m_mou_8, Length: 16073, dtype: int64
# loc_ic_t2f_mou_6 Unique Values = 0.00      10327
# 0.23         77
# 0.38         65
# 0.33         65
# 0.61         64
#           ...
# 49.86         1
# 285.18        1
# 123.36        1
# 54.41         1
# 411.34        1
# Name: loc_ic_t2f_mou_6, Length: 4695, dtype: int64
# loc_ic_t2f_mou_7 Unique Values = 0.00      9217
# 0.50        82
# 0.41        76
# 0.38        73
# 0.28        72
#           ...
# 136.66       1
# 135.36       1
# 35.61        1
# 143.23       1
# 465.71       1
# Name: loc_ic_t2f_mou_7, Length: 4867, dtype: int64
# loc_ic_t2f_mou_8 Unique Values = 0.00      8554
# 0.45        91
# 0.41        89
# 0.38        83
# 0.46        75
#           ...
# 215.76       1
# 63.28        1
# 153.68       1
# 56.68        1
# 317.86       1
# Name: loc_ic_t2f_mou_8, Length: 4830, dtype: int64
# loc_ic_mou_6 Unique Values = 0.00      1597
# 6.34         9
# 0.83         8
# 108.89       8
# 24.24        8
#           ...
# 242.93       1
# 409.09       1
# 355.46       1
# 252.61       1
# 307.31       1
# Name: loc_ic_mou_6, Length: 18189, dtype: int64
# loc_ic_mou_7 Unique Values = 0.00       795
# 4.48         9
# 59.84        8
# 16.43        7
# 126.21       7
#           ...
# 1179.11      1
# 455.41       1
# 164.08       1
# 292.76       1
# 337.28       1
# Name: loc_ic_mou_7, Length: 18630, dtype: int64
# loc_ic_mou_8 Unique Values = 0.00       342
# 54.34       10
# 59.53        8
# 3.31         8
# 31.84        8
#           ...
# 211.04       1
# 2.25         1
# 2605.96      1
# 429.43       1
# 1144.64      1
# Name: loc_ic_mou_8, Length: 19148, dtype: int64
# std_ic_t2t_mou_6 Unique Values = 0.00      13301
# 0.03        116
# 0.18         66
# 0.05         65
# 0.01         64
#           ...
# 58.09         1
# 73.23         1
# 130.64        1
# 45.13         1
# 57.60         1
# Name: std_ic_t2t_mou_6, Length: 4289, dtype: int64
# std_ic_t2t_mou_7 Unique Values = 0.00      12200
# 0.03        107
# 0.01         76
# 0.06         65
# 0.16         61
#           ...
# 136.71        1
# 23.51         1
# 59.44         1
# 46.23         1
# 30.34         1
# Name: std_ic_t2t_mou_7, Length: 4572, dtype: int64
# std_ic_t2t_mou_8 Unique Values = 0.00      11444
# 0.03        122
# 0.01         84
# 0.05         77
# 0.31         69
#           ...
# 414.71        1
# 59.83         1
# 113.98        1
# 126.83        1
# 443.28        1
# Name: std_ic_t2t_mou_8, Length: 4680, dtype: int64
# std_ic_t2m_mou_6 Unique Values = 0.00      7708
# 0.03        61
# 0.31        56
# 0.30        54
# 0.26        54
#           ...
# 138.88       1
# 111.04       1
# 66.96        1
# 48.71        1
# 680.34       1
# Name: std_ic_t2m_mou_6, Length: 6251, dtype: int64
# std_ic_t2m_mou_7 Unique Values = 0.00      6709
# 0.03        92
# 0.23        59
# 0.25        52
# 0.05        51
#           ...
# 55.41        1
# 67.49        1
# 119.19       1
# 44.59        1
# 37.58        1
# Name: std_ic_t2m_mou_7, Length: 6556, dtype: int64
# std_ic_t2m_mou_8 Unique Values = 0.00      5822
# 0.03        72
# 0.01        59
# 0.31        58
# 0.43        55
#           ...
# 80.69        1
# 27.61        1
# 147.53       1
# 322.26       1
# 220.69       1
# Name: std_ic_t2m_mou_8, Length: 6737, dtype: int64
# std_ic_t2f_mou_6 Unique Values = 0.00     21986
# 0.31        62
# 0.43        60
# 0.56        56
# 0.20        55
#          ...
# 42.71        1
# 14.44        1
# 22.44        1
# 18.98        1
# 41.59        1
# Name: std_ic_t2f_mou_6, Length: 1965, dtype: int64
# std_ic_t2f_mou_7 Unique Values = 0.00     21542
# 0.48        64
# 0.26        59
# 0.31        52
# 0.20        52
#          ...
# 44.34        1
# 47.58        1
# 12.79        1
# 99.88        1
# 8.25         1
# Name: std_ic_t2f_mou_7, Length: 2033, dtype: int64
# std_ic_t2f_mou_8 Unique Values = 0.00      21388
# 0.33         66
# 0.30         54
# 0.41         53
# 0.51         53
#           ...
# 179.19        1
# 12.53         1
# 69.34         1
# 42.13         1
# 24.71         1
# Name: std_ic_t2f_mou_8, Length: 1985, dtype: int64
# std_ic_t2o_mou_6 Unique Values = 0.0    29487
# Name: std_ic_t2o_mou_6, dtype: int64
# std_ic_t2o_mou_7 Unique Values = 0.0    29487
# Name: std_ic_t2o_mou_7, dtype: int64
# std_ic_t2o_mou_8 Unique Values = 0.0    29487
# Name: std_ic_t2o_mou_8, dtype: int64
# std_ic_mou_6 Unique Values = 0.00      4971
# 0.31        51
# 0.43        50
# 0.03        50
# 0.26        47
#           ...
# 82.21        1
# 882.83       1
# 63.58        1
# 80.21        1
# 691.44       1
# Name: std_ic_mou_6, Length: 7875, dtype: int64
# std_ic_mou_7 Unique Values = 0.00      3983
# 0.03        63
# 0.48        43
# 0.21        40
# 0.13        39
#           ...
# 147.68       1
# 82.48        1
# 75.29        1
# 74.24        1
# 351.78       1
# Name: std_ic_mou_7, Length: 8259, dtype: int64
# std_ic_mou_8 Unique Values = 0.00      3230
# 0.03        48
# 0.31        46
# 0.51        44
# 0.23        39
#           ...
# 269.23       1
# 877.56       1
# 132.11       1
# 82.96        1
# 88.86        1
# Name: std_ic_mou_8, Length: 8437, dtype: int64
# total_ic_mou_6 Unique Values = 0.00       1477
# 14.71         8
# 33.43         8
# 0.18          8
# 42.84         8
#            ...
# 1220.81       1
# 792.54        1
# 269.58        1
# 2858.13       1
# 998.96        1
# Name: total_ic_mou_6, Length: 19748, dtype: int64
# total_ic_mou_7 Unique Values = 0.00      718
# 84.14       7
# 92.24       6
# 142.49      6
# 96.93       6
#          ...
# 302.78      1
# 146.19      1
# 337.58      1
# 558.29      1
# 11.09       1
# Name: total_ic_mou_7, Length: 20305, dtype: int64
# total_ic_mou_8 Unique Values = 0.00      306
# 151.84      9
# 74.06       7
# 122.24      7
# 47.19       6
#          ...
# 425.13      1
# 236.38      1
# 62.06       1
# 384.26      1
# 2.29        1
# Name: total_ic_mou_8, Length: 20701, dtype: int64
# spl_ic_mou_6 Unique Values = 0.00    23044
# 0.15      654
# 0.13      279
# 0.30      275
# 0.06      269
#         ...
# 1.33        1
# 3.56        1
# 0.99        1
# 2.18        1
# 2.83        1
# Name: spl_ic_mou_6, Length: 76, dtype: int64
# spl_ic_mou_7 Unique Values = 0.00    27513
# 0.20      309
# 0.06      106
# 0.40       93
# 0.18       87
#         ...
# 1.06        1
# 1.16        1
# 0.83        1
# 1.10        1
# 5.88        1
# Name: spl_ic_mou_7, Length: 93, dtype: int64
# spl_ic_mou_8 Unique Values = 0.00    26552
# 0.25      596
# 0.50      303
# 0.21      124
# 0.75      106
#         ...
# 1.01        1
# 0.85        1
# 1.25        1
# 0.79        1
# 1.11        1
# Name: spl_ic_mou_8, Length: 86, dtype: int64
# isd_ic_mou_6 Unique Values = 0.00      23336
# 0.01        124
# 0.03        102
# 0.05         64
# 0.50         36
#           ...
# 29.96         1
# 17.51         1
# 10.81         1
# 143.59        1
# 108.38        1
# Name: isd_ic_mou_6, Length: 3173, dtype: int64
# isd_ic_mou_7 Unique Values = 0.00     22808
# 0.01        50
# 0.46        40
# 0.05        36
# 0.03        35
#          ...
# 22.68        1
# 36.83        1
# 19.50        1
# 37.90        1
# 9.60         1
# Name: isd_ic_mou_7, Length: 3450, dtype: int64
# isd_ic_mou_8 Unique Values = 0.00      22726
# 0.01         47
# 0.03         44
# 0.46         42
# 0.45         39
#           ...
# 101.76        1
# 44.51         1
# 966.09        1
# 58.98         1
# 65.81         1
# Name: isd_ic_mou_8, Length: 3611, dtype: int64
# ic_others_6 Unique Values = 0.00     22068
# 0.48       225
# 0.06       222
# 0.15       189
# 0.05       171
#          ...
# 13.01        1
# 42.73        1
# 97.06        1
# 9.19         1
# 20.69        1
# Name: ic_others_6, Length: 1146, dtype: int64
# ic_others_7 Unique Values = 0.00     22267
# 0.10       136
# 0.06       122
# 0.05       115
# 0.08       115
#          ...
# 14.06        1
# 14.13        1
# 18.90        1
# 7.88         1
# 39.34        1
# Name: ic_others_7, Length: 1327, dtype: int64
# ic_others_8 Unique Values = 0.00     21351
# 0.10       273
# 0.06       238
# 0.08       231
# 0.13       170
#          ...
# 9.39         1
# 26.38        1
# 21.44        1
# 30.40        1
# 10.03        1
# Name: ic_others_8, Length: 1282, dtype: int64
# total_rech_num_6 Unique Values = 6      2715
# 5      2616
# 7      2411
# 4      2246
# 8      2163
#        ...
# 121       1
# 83        1
# 89        1
# 117       1
# 73        1
# Name: total_rech_num_6, Length: 92, dtype: int64
# total_rech_num_7 Unique Values = 5      2594
# 6      2506
# 4      2291
# 7      2215
# 8      2036
#        ...
# 83        1
# 119       1
# 78        1
# 138       1
# 120       1
# Name: total_rech_num_7, Length: 96, dtype: int64
# total_rech_num_8 Unique Values = 5      2364
# 6      2293
# 4      2199
# 7      2123
# 8      2014
#        ...
# 196       1
# 108       1
# 73        1
# 121       1
# 96        1
# Name: total_rech_num_8, Length: 95, dtype: int64
# total_rech_amt_6 Unique Values = 0       1358
# 330      292
# 110      275
# 220      264
# 250      248
#         ...
# 1874       1
# 2670       1
# 1685       1
# 2222       1
# 1395       1
# Name: total_rech_amt_6, Length: 2183, dtype: int64
# total_rech_amt_7 Unique Values = 0       867
# 330     304
# 220     277
# 250     252
# 110     233
#        ...
# 2328      1
# 3588      1
# 2101      1
# 2194      1
# 2403      1
# Name: total_rech_amt_7, Length: 2243, dtype: int64
# total_rech_amt_8 Unique Values = 390     533
# 500     385
# 400     329
# 520     229
# 380     226
#        ...
# 2763      1
# 1633      1
# 1956      1
# 5800      1
# 1459      1
# Name: total_rech_amt_8, Length: 1950, dtype: int64
# max_rech_amt_6 Unique Values = 110     7794
# 120     2225
# 50      2141
# 154     1498
# 128     1381
#         ...
# 3150       1
# 299        1
# 405        1
# 3299       1
# 24         1
# Name: max_rech_amt_6, Length: 167, dtype: int64
# max_rech_amt_7 Unique Values = 110     6235
# 50      2375
# 128     2331
# 120     1654
# 154     1560
#         ...
# 66         1
# 22         1
# 175        1
# 1099       1
# 800        1
# Name: max_rech_amt_7, Length: 155, dtype: int64
# max_rech_amt_8 Unique Values = 130    7143
# 50     2010
# 252    1863
# 144    1726
# 150    1626
#        ...
# 51        1
# 22        1
# 650       1
# 209       1
# 295       1
# Name: max_rech_amt_8, Length: 171, dtype: int64
# date_of_last_rech_6 Unique Values = 6/30/2014    7429
# 6/29/2014    4981
# 6/28/2014    3486
# 6/27/2014    3304
# 6/26/2014    1771
# 6/25/2014    1327
# 6/24/2014    1154
# 6/21/2014     769
# 6/23/2014     756
# 6/14/2014     681
# 6/17/2014     639
# 6/22/2014     582
# 6/19/2014     430
# 6/18/2014     429
# 6/20/2014     420
# 6/12/2014     266
# 6/13/2014     266
# 6/16/2014     204
# 6/15/2014     159
# 6/11/2014      90
# 6/8/2014       79
# 6/7/2014       46
# 6/10/2014      42
# 6/5/2014       41
# 6/9/2014       40
# 6/1/2014       27
# 6/3/2014       24
# 6/4/2014       17
# 6/2/2014       16
# 6/6/2014       12
# Name: date_of_last_rech_6, dtype: int64
# date_of_last_rech_7 Unique Values = 7/31/2014    7661
# 7/30/2014    5005
# 7/29/2014    3363
# 7/28/2014    2839
# 7/25/2014    2156
# 7/27/2014    1674
# 7/26/2014    1571
# 7/24/2014     886
# 7/22/2014     694
# 7/23/2014     539
# 7/16/2014     475
# 7/20/2014     460
# 7/21/2014     388
# 7/19/2014     379
# 7/17/2014     352
# 7/15/2014     292
# 7/18/2014     240
# 7/10/2014      78
# 7/12/2014      77
# 7/9/2014       77
# 7/14/2014      56
# 7/13/2014      54
# 7/11/2014      34
# 7/6/2014       25
# 7/8/2014       24
# 7/4/2014       20
# 7/7/2014       19
# 7/5/2014       14
# 7/3/2014       14
# 7/1/2014       11
# 7/2/2014       10
# Name: date_of_last_rech_7, dtype: int64
# date_of_last_rech_8 Unique Values = 8/31/2014    7794
# 8/30/2014    5467
# 8/29/2014    3555
# 8/28/2014    2991
# 8/27/2014    2066
# 8/26/2014    1802
# 8/25/2014    1767
# 8/24/2014     985
# 8/23/2014     507
# 8/22/2014     437
# 8/20/2014     378
# 8/21/2014     348
# 8/19/2014     273
# 8/18/2014     162
# 8/17/2014     134
# 8/16/2014     117
# 8/14/2014     102
# 8/15/2014      99
# 8/13/2014      81
# 8/12/2014      73
# 8/9/2014       58
# 8/11/2014      57
# 8/5/2014       46
# 8/7/2014       38
# 8/10/2014      34
# 8/8/2014       33
# 8/6/2014       32
# 8/2/2014       18
# 8/4/2014       14
# 8/3/2014       10
# 8/1/2014        9
# Name: date_of_last_rech_8, dtype: int64
# last_day_rch_amt_6 Unique Values = 110     6768
# 0       5290
# 30      2919
# 50      2525
# 120     1709
#         ...
# 155        1
# 5          1
# 1580       1
# 95         1
# 230        1
# Name: last_day_rch_amt_6, Length: 150, dtype: int64
# last_day_rch_amt_7 Unique Values = 0       5240
# 110     3603
# 30      2916
# 50      2673
# 130     1873
#         ...
# 855        1
# 175        1
# 1255       1
# 78         1
# 153        1
# Name: last_day_rch_amt_7, Length: 144, dtype: int64
# last_day_rch_amt_8 Unique Values = 130     6805
# 0       4290
# 50      2619
# 30      2517
# 20      1089
#         ...
# 650        1
# 209        1
# 1555       1
# 1699       1
# 108        1
# Name: last_day_rch_amt_8, Length: 176, dtype: int64
# vol_2g_mb_6 Unique Values = 0.00       20636
# 0.01          51
# 0.02          32
# 0.03          19
# 0.05          18
#            ...
# 411.41         1
# 843.35         1
# 97.44          1
# 43.28          1
# 2198.07        1
# Name: vol_2g_mb_6, Length: 7025, dtype: int64
# vol_2g_mb_7 Unique Values = 0.00      20095
# 0.02         37
# 0.01         35
# 0.04         25
# 0.03         18
#           ...
# 4.77          1
# 129.26        1
# 420.78        1
# 2.89          1
# 241.77        1
# Name: vol_2g_mb_7, Length: 7338, dtype: int64
# vol_2g_mb_8 Unique Values = 0.00      18851
# 0.01         58
# 0.02         43
# 0.03         29
# 0.07         27
#           ...
# 335.04        1
# 290.41        1
# 204.47        1
# 6.89          1
# 136.47        1
# Name: vol_2g_mb_8, Length: 8045, dtype: int64
# vol_3g_mb_6 Unique Values = 0.00       23079
# 0.01           9
# 0.06           4
# 0.34           3
# 0.03           3
#            ...
# 818.70         1
# 3450.94        1
# 0.18           1
# 1629.44        1
# 1453.63        1
# Name: vol_3g_mb_6, Length: 6274, dtype: int64
# vol_3g_mb_7 Unique Values = 0.00       22451
# 0.01           6
# 0.10           4
# 0.21           4
# 0.11           4
#            ...
# 336.65         1
# 317.70         1
# 1.84           1
# 1016.76        1
# 1382.08        1
# Name: vol_3g_mb_7, Length: 6873, dtype: int64
# vol_3g_mb_8 Unique Values = 0.00       21444
# 0.01          12
# 0.03           7
# 0.13           6
# 0.02           6
#            ...
# 5486.04        1
# 2258.69        1
# 1642.76        1
# 750.37         1
# 2683.30        1
# Name: vol_3g_mb_8, Length: 7804, dtype: int64
# monthly_2g_6 Unique Values = 0    26469
# 1     2725
# 2      270
# 3       20
# 4        3
# Name: monthly_2g_6, dtype: int64
# monthly_2g_7 Unique Values = 0    26225
# 1     2915
# 2      323
# 3       19
# 4        3
# 5        2
# Name: monthly_2g_7, dtype: int64
# monthly_2g_8 Unique Values = 0    25800
# 1     3198
# 2      445
# 3       36
# 4        6
# 5        2
# Name: monthly_2g_8, dtype: int64
# sachet_2g_6 Unique Values = 0     24864
# 1      2176
# 2       896
# 3       507
# 4       330
# 5       175
# 6       135
# 7        85
# 8        76
# 9        58
# 10       40
# 12       34
# 11       27
# 13       21
# 15       10
# 14       10
# 17        9
# 18        6
# 19        5
# 22        4
# 16        4
# 21        3
# 25        3
# 20        3
# 32        1
# 39        1
# 24        1
# 27        1
# 30        1
# 34        1
# Name: sachet_2g_6, dtype: int64
# sachet_2g_7 Unique Values = 0     24429
# 1      2048
# 2       938
# 3       527
# 4       394
# 5       337
# 6       226
# 7       155
# 8       120
# 9        65
# 10       60
# 11       49
# 12       34
# 14       19
# 13       17
# 15       13
# 16       10
# 18        8
# 19        8
# 17        7
# 21        4
# 20        4
# 27        3
# 22        2
# 30        2
# 26        2
# 29        1
# 25        1
# 23        1
# 48        1
# 42        1
# 32        1
# Name: sachet_2g_7, dtype: int64
# sachet_2g_8 Unique Values = 0     23269
# 1      2629
# 2      1034
# 3       668
# 4       524
# 5       423
# 6       269
# 7       170
# 8       118
# 9        82
# 10       59
# 11       49
# 12       43
# 14       30
# 13       25
# 15       21
# 16       15
# 18       11
# 19       10
# 17        8
# 20        5
# 24        4
# 25        4
# 22        3
# 21        2
# 29        2
# 34        2
# 27        2
# 26        1
# 33        1
# 44        1
# 31        1
# 23        1
# 32        1
# Name: sachet_2g_8, dtype: int64
# monthly_3g_6 Unique Values = 0     26524
# 1      2165
# 2       533
# 3       160
# 4        56
# 5        24
# 6        10
# 7         7
# 8         3
# 9         2
# 11        2
# 14        1
# Name: monthly_3g_6, dtype: int64
# monthly_3g_7 Unique Values = 0     26283
# 1      2252
# 2       649
# 3       166
# 4        60
# 5        32
# 6        21
# 7         9
# 8         5
# 9         4
# 11        2
# 12        1
# 14        1
# 10        1
# 16        1
# Name: monthly_3g_7, dtype: int64
# monthly_3g_8 Unique Values = 0     25635
# 1      2639
# 2       848
# 3       216
# 4        86
# 5        29
# 6        14
# 7        11
# 8         3
# 9         3
# 10        2
# 16        1
# Name: monthly_3g_8, dtype: int64
# sachet_3g_6 Unique Values = 0     27793
# 1      1152
# 2       261
# 3        93
# 4        45
# 5        38
# 7        20
# 6        20
# 9        14
# 11        9
# 8         8
# 10        7
# 15        3
# 19        3
# 14        3
# 18        3
# 12        3
# 13        3
# 16        2
# 29        2
# 22        2
# 17        1
# 28        1
# 23        1
# Name: sachet_3g_6, dtype: int64
# sachet_3g_7 Unique Values = 0     27685
# 1      1154
# 2       282
# 3       106
# 4        60
# 5        59
# 6        38
# 9        15
# 7        14
# 8        12
# 11       11
# 10        9
# 12        9
# 13        5
# 15        4
# 18        4
# 14        4
# 19        3
# 22        3
# 20        3
# 21        2
# 17        1
# 33        1
# 24        1
# 31        1
# 16        1
# Name: sachet_3g_7, dtype: int64
# sachet_3g_8 Unique Values = 0     27494
# 1      1195
# 2       322
# 3       148
# 4        82
# 5        68
# 6        30
# 7        28
# 8        23
# 10       16
# 9        15
# 12       13
# 13       12
# 11        8
# 14        7
# 15        5
# 20        3
# 18        3
# 23        2
# 16        2
# 21        2
# 17        2
# 41        1
# 29        1
# 19        1
# 38        1
# 25        1
# 27        1
# 30        1
# Name: sachet_3g_8, dtype: int64
# aon Unique Values = 3651    524
# 2372    222
# 495     106
# 494      87
# 492      85
#        ...
# 3159      1
# 3609      1
# 3365      1
# 3538      1
# 3562      1
# Name: aon, Length: 3321, dtype: int64
# aug_vbc_3g Unique Values = 0.00       21551
# 0.30           6
# 0.17           5
# 0.05           5
# 0.57           4
#            ...
# 126.57         1
# 341.05         1
# 1.84           1
# 566.07         1
# 1445.74        1
# Name: aug_vbc_3g, Length: 7538, dtype: int64
# jul_vbc_3g Unique Values = 0.00       22275
# 0.03           5
# 0.14           4
# 0.02           4
# 24.03          4
#            ...
# 0.37           1
# 2945.06        1
# 121.03         1
# 597.44         1
# 1151.03        1
# Name: jul_vbc_3g, Length: 6878, dtype: int64
# jun_vbc_3g Unique Values = 0.00       22894
# 2.21           4
# 1.01           4
# 0.06           4
# 0.49           3
#            ...
# 50.89          1
# 569.61         1
# 349.09         1
# 251.66         1
# 1173.18        1
# Name: jun_vbc_3g, Length: 6284, dtype: int64
# sep_vbc_3g Unique Values = 0.00      26729
# 2.10          7
# 0.06          7
# 0.11          6
# 0.22          5
#           ...
# 1.54          1
# 8.15          1
# 107.13        1
# 34.61         1
# 45.89         1
# Name: sep_vbc_3g, Length: 2321, dtype: int64
# Avg_Rech Unique Values = 0.0       281
# 500.0     115
# 275.0     113
# 250.0     103
# 300.0      99
#          ...
# 1559.5      1
# 1164.5      1
# 2012.5      1
# 1727.0      1
# 1878.0      1
# Name: Avg_Rech, Length: 3589, dtype: int64
# Good_Phase_Rech Unique Values = 368.5    29487
# Name: Good_Phase_Rech, dtype: int64
# HV_Customer Unique Values = True    29487
# Name: HV_Customer, dtype: int64
# Churn Unique Values = 0    28442
# 1     1045
# Name: Churn, dtype: int64

# %%
## Dropping the columns having only same values thru the rows

HV_Data=HV_Data.drop(labels=["std_ic_t2o_mou_6","std_ic_t2o_mou_7","std_ic_t2o_mou_8","Good_Phase_Rech","HV_Customer","std_og_t2c_mou_6","std_og_t2c_mou_7","std_og_t2c_mou_8","loc_og_t2o_mou","std_og_t2o_mou","loc_ic_t2o_mou","last_date_of_month_6","last_date_of_month_7","last_date_of_month_8"],axis=1)
HV_Data.shape
# Out:
# (29487, 132)

# %%
## Dropping the Subset columns of Local, STD Incoming and Outgoing calls
cols_to_drop = ["loc_og_t2t_mou_6","loc_og_t2t_mou_7","loc_og_t2t_mou_8",
               "loc_og_t2m_mou_6","loc_og_t2m_mou_7","loc_og_t2m_mou_8",
               "loc_og_t2f_mou_6","loc_og_t2f_mou_7","loc_og_t2f_mou_8",
               "loc_og_t2c_mou_6","loc_og_t2c_mou_7","loc_og_t2c_mou_8",
               "std_og_t2t_mou_6","std_og_t2t_mou_7","std_og_t2t_mou_8",
               "std_og_t2m_mou_6","std_og_t2m_mou_7","std_og_t2m_mou_8",
               "std_og_t2f_mou_6","std_og_t2f_mou_7","std_og_t2f_mou_8",
               "loc_ic_t2t_mou_6","loc_ic_t2t_mou_7","loc_ic_t2t_mou_8",
               "loc_ic_t2m_mou_6","loc_ic_t2m_mou_7","loc_ic_t2m_mou_8",
               "loc_ic_t2f_mou_6","loc_ic_t2f_mou_7","loc_ic_t2f_mou_8",
               "std_ic_t2t_mou_6","std_ic_t2t_mou_7","std_ic_t2t_mou_8",
               "std_ic_t2m_mou_6","std_ic_t2m_mou_7","std_ic_t2m_mou_8",
               "std_ic_t2f_mou_6","std_ic_t2f_mou_7","std_ic_t2f_mou_8","sep_vbc_3g",
                "date_of_last_rech_6","date_of_last_rech_7","date_of_last_rech_8"]

HV_Data.drop(cols_to_drop, inplace=True, axis=1)
HV_Data.shape
# Out:
# (29487, 89)

# %%
HV_Data.columns.to_list
# Out:
# <bound method IndexOpsMixin.tolist of Index(['mobile_number', 'circle_id', 'arpu_6', 'arpu_7', 'arpu_8',
#        'onnet_mou_6', 'onnet_mou_7', 'onnet_mou_8', 'offnet_mou_6',
#        'offnet_mou_7', 'offnet_mou_8', 'roam_ic_mou_6', 'roam_ic_mou_7',
#        'roam_ic_mou_8', 'roam_og_mou_6', 'roam_og_mou_7', 'roam_og_mou_8',
#        'loc_og_mou_6', 'loc_og_mou_7', 'loc_og_mou_8', 'std_og_mou_6',
#        'std_og_mou_7', 'std_og_mou_8', 'isd_og_mou_6', 'isd_og_mou_7',
#        'isd_og_mou_8', 'spl_og_mou_6', 'spl_og_mou_7', 'spl_og_mou_8',
#        'og_others_6', 'og_others_7', 'og_others_8', 'total_og_mou_6',
#        'total_og_mou_7', 'total_og_mou_8', 'loc_ic_mou_6', 'loc_ic_mou_7',
#        'loc_ic_mou_8', 'std_ic_mou_6', 'std_ic_mou_7', 'std_ic_mou_8',
#        'total_ic_mou_6', 'total_ic_mou_7', 'total_ic_mou_8', 'spl_ic_mou_6',
#        'spl_ic_mou_7', 'spl_ic_mou_8', 'isd_ic_mou_6', 'isd_ic_mou_7',
#        'isd_ic_mou_8', 'ic_others_6', 'ic_others_7', 'ic_others_8',
#        'total_rech_num_6', 'total_rech_num_7', 'total_rech_num_8',
#        'total_rech_amt_6', 'total_rech_amt_7', 'total_rech_amt_8',
#        'max_rech_amt_6', 'max_rech_amt_7', 'max_rech_amt_8',
#        'last_day_rch_amt_6', 'last_day_rch_amt_7', 'last_day_rch_amt_8',
#        'vol_2g_mb_6', 'vol_2g_mb_7', 'vol_2g_mb_8', 'vol_3g_mb_6',
#        'vol_3g_mb_7', 'vol_3g_mb_8', 'monthly_2g_6', 'monthly_2g_7',
#        'monthly_2g_8', 'sachet_2g_6', 'sachet_2g_7', 'sachet_2g_8',
#        'monthly_3g_6', 'monthly_3g_7', 'monthly_3g_8', 'sachet_3g_6',
#        'sachet_3g_7', 'sachet_3g_8', 'aon', 'aug_vbc_3g', 'jul_vbc_3g',
#        'jun_vbc_3g', 'Avg_Rech', 'Churn'],
#       dtype='object')>

# %% [markdown]
# ## Train Test Split

# %%
## # splitting dataset into train and test
from sklearn.model_selection import train_test_split
y = HV_Data.Churn
X = HV_Data.drop('Churn', axis=1)
X = X.drop('mobile_number', axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify = y, random_state=56)

# %%
print(y_train.value_counts())
y_train.value_counts(normalize = True).reset_index()
# Out:
# 0    19909
# 1      731
# Name: Churn, dtype: int64
#    index     Churn
# 0      0  0.964583
# 1      1  0.035417

# %%
print(y_test.value_counts())
y_test.value_counts(normalize = True).reset_index()
# Out:
# 0    8533
# 1     314
# Name: Churn, dtype: int64
#    index     Churn
# 0      0  0.964508
# 1      1  0.035492

# %% [markdown]
# ## Handling Imbalanced Data

# %%
# Handling Imbalanced Data Set

print(HV_Data.Churn.value_counts())
HV_Data.Churn.value_counts(normalize = True).reset_index()
# Out:
# 0    28442
# 1     1045
# Name: Churn, dtype: int64
#    index     Churn
# 0      0  0.964561
# 1      1  0.035439

# %%
colors = ["#0101DF", "#DF0101"]

sns.countplot('Churn', data=HV_Data, palette=colors)
plt.title('Class Distributions \n (0: No Claim || 1: Claim)', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Class Distributions \n (0: No Claim || 1: Claim)')

# %%
pip install imbalanced-learn --trusted-host pypi.org --trusted-host pypi.python.org --trusted-host=files.pythonhosted.org
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\sagkumar\anaconda3\lib\site-packages (0.11.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: scipy>=1.5.0 in c:\users\sagkumar\anaconda3\lib\site-packages (from imbalanced-learn) (1.9.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\sagkumar\anaconda3\lib\site-packages (from imbalanced-learn) (2.2.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\sagkumar\anaconda3\lib\site-packages (from imbalanced-learn) (1.0.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\sagkumar\anaconda3\lib\site-packages (from imbalanced-learn) (1.3.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\sagkumar\anaconda3\lib\site-packages (from imbalanced-learn) (1.21.5)

# %%
# SMOTE+TOMEK
from imblearn.combine import SMOTETomek
smt_tmk = SMOTETomek(random_state=45)
X_resampled_smt_tmk, y_resampled_smt_tmk = smt_tmk.fit_resample(X_train, y_train)
len(X_resampled_smt_tmk)
# Out:
# 39796

# %%
X_resampled_smt_tmk.describe()
# Out:
#        circle_id        arpu_6        arpu_7        arpu_8   onnet_mou_6  \
# count    39796.0  39796.000000  39796.000000  39796.000000  39796.000000
# mean       109.0    501.847377    552.319846    582.633866    271.543028
# std          0.0    442.713877    422.796786    363.988359    467.417798
# min        109.0   -810.661000   -275.799000   -345.129000      0.000000
# 25%        109.0    231.080824    289.039153    385.228361     23.727905
# 50%        109.0    404.947832    466.152964    485.330271     96.422888
# 75%        109.0    660.124073    705.161301    657.010747    291.665000
# max        109.0  11261.349000  16820.145000  19295.904000   6944.360000
#
#         onnet_mou_7   onnet_mou_8  offnet_mou_6  offnet_mou_7  offnet_mou_8  \
# count  39796.000000  39796.000000  39796.000000  39796.000000  39796.000000
# mean     303.313662    292.800101    353.810763    419.660556    394.463268
# std      499.043319    445.736975    490.178058    584.357600    443.716124
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       31.389456     40.837500     70.811522     95.039786    121.437233
# 50%      111.417597    124.720000    197.112485    232.070000    255.734718
# 75%      344.829572    362.208086    436.602132    509.395000    512.413897
# max     8157.780000  10752.560000   6962.460000   9667.130000  13547.840000
#
#        ...  monthly_3g_7  monthly_3g_8   sachet_3g_6   sachet_3g_7  \
# count  ...  39796.000000  39796.000000  39796.000000  39796.000000
# mean   ...      0.132526      0.135843      0.084682      0.098427
# std    ...      0.562984      0.516778      0.633183      0.722434
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...      0.000000      0.000000      0.000000      0.000000
# 50%    ...      0.000000      0.000000      0.000000      0.000000
# 75%    ...      0.000000      0.000000      0.000000      0.000000
# max    ...     16.000000     16.000000     29.000000     22.000000
#
#         sachet_3g_8           aon    aug_vbc_3g    jul_vbc_3g    jun_vbc_3g  \
# count  39796.000000  39796.000000  39796.000000  39796.000000  39796.000000
# mean       0.106242   1105.899663     96.620077    101.111816     90.025805
# std        0.773782    884.225482    325.935420    344.369467    319.422711
# min        0.000000    180.000000      0.000000      0.000000      0.000000
# 25%        0.000000    460.000000      0.000000      0.000000      0.000000
# 50%        0.000000    765.000000      0.000000      0.000000      0.000000
# 75%        0.000000   1481.250000      3.203653      0.000000      0.000000
# max       41.000000   4319.000000  12916.220000   9165.600000  11166.210000
#
#            Avg_Rech
# count  39796.000000
# mean     615.921070
# std      476.761328
# min        0.000000
# 25%      323.500000
# 50%      510.434826
# 75%      791.000000
# max    16150.000000
#
# [8 rows x 87 columns]

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_resampled_smt_tmk[X_resampled_smt_tmk.columns] = scaler.fit_transform(X_resampled_smt_tmk[X_resampled_smt_tmk.columns])

# %%
X_resampled_smt_tmk.describe()
# Out:
#        circle_id        arpu_6        arpu_7        arpu_8   onnet_mou_6  \
# count    39796.0  39796.000000  39796.000000  39796.000000  39796.000000
# mean         0.0      0.108723      0.048439      0.047236      0.039103
# std          0.0      0.036673      0.024731      0.018532      0.067309
# min          0.0      0.000000      0.000000      0.000000      0.000000
# 25%          0.0      0.086294      0.033039      0.037185      0.003417
# 50%          0.0      0.100696      0.043399      0.042282      0.013885
# 75%          0.0      0.121834      0.057380      0.051023      0.042000
# max          0.0      1.000000      1.000000      1.000000      1.000000
#
#         onnet_mou_7   onnet_mou_8  offnet_mou_6  offnet_mou_7  offnet_mou_8  \
# count  39796.000000  39796.000000  39796.000000  39796.000000  39796.000000
# mean       0.037181      0.027231      0.050817      0.043411      0.029116
# std        0.061174      0.041454      0.070403      0.060448      0.032752
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.003848      0.003798      0.010170      0.009831      0.008964
# 50%        0.013658      0.011599      0.028311      0.024006      0.018876
# 75%        0.042270      0.033686      0.062708      0.052694      0.037823
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#        ...  monthly_3g_7  monthly_3g_8   sachet_3g_6   sachet_3g_7  \
# count  ...  39796.000000  39796.000000  39796.000000  39796.000000
# mean   ...      0.008283      0.008490      0.002920      0.004474
# std    ...      0.035186      0.032299      0.021834      0.032838
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...      0.000000      0.000000      0.000000      0.000000
# 50%    ...      0.000000      0.000000      0.000000      0.000000
# 75%    ...      0.000000      0.000000      0.000000      0.000000
# max    ...      1.000000      1.000000      1.000000      1.000000
#
#         sachet_3g_8           aon    aug_vbc_3g    jul_vbc_3g    jun_vbc_3g  \
# count  39796.000000  39796.000000  39796.000000  39796.000000  39796.000000
# mean       0.002591      0.223701      0.007481      0.011032      0.008062
# std        0.018873      0.213633      0.025235      0.037572      0.028606
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.067649      0.000000      0.000000      0.000000
# 50%        0.000000      0.141338      0.000000      0.000000      0.000000
# 75%        0.000000      0.314388      0.000248      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#            Avg_Rech
# count  39796.000000
# mean       0.038138
# std        0.029521
# min        0.000000
# 25%        0.020031
# 50%        0.031606
# 75%        0.048978
# max        1.000000
#
# [8 rows x 87 columns]

# %% [markdown]
# ## Checking correlation among Features

# %%
## Correlation for ARPU,ONNET,OFFNET,ROAM

# check correlation of continuous vars with target
conti_cols = ['arpu_6', 'arpu_7', 'arpu_8',
              'onnet_mou_6', 'onnet_mou_7', 'onnet_mou_8',
              'offnet_mou_6','offnet_mou_7','offnet_mou_8',
              "roam_ic_mou_6","roam_ic_mou_7","roam_ic_mou_8",
              "roam_og_mou_6","roam_og_mou_7","roam_og_mou_8","Churn"
             ]

# Finding out the correlation between the features
conti_cols_corr = HV_Data[conti_cols].corr()

# Plotting the heatmap of correlation between features
plt.figure(figsize=(20,20))
sns.heatmap(conti_cols_corr, cbar=True, square= True, fmt='.2f', annot=True, annot_kws={'size':15}, cmap='Greens')
# Out:
# <AxesSubplot:>

# %%
## Correlation for Outgoing Calls

# check correlation of continuous vars with target
conti_cols = ["loc_og_mou_6","loc_og_mou_7","loc_og_mou_8",
              "std_og_mou_6","std_og_mou_7","std_og_mou_8",
              "isd_og_mou_6","isd_og_mou_7","isd_og_mou_8",
              "spl_og_mou_6","spl_og_mou_7","spl_og_mou_8",
              'og_others_6','og_others_7','og_others_8',
              "total_og_mou_6","total_og_mou_7","total_og_mou_8","Churn"
             ]

# Finding out the correlation between the features
conti_cols_corr = HV_Data[conti_cols].corr()

# Plotting the heatmap of correlation between features
plt.figure(figsize=(30,25))
sns.heatmap(conti_cols_corr, cbar=True, square= True, fmt='.2f', annot=True, annot_kws={'size':15}, cmap='Greens')
# Out:
# <AxesSubplot:>

# %%
## Correlation for Incoming Calls

# check correlation of continuous vars with target
conti_cols = ["loc_ic_mou_6","loc_ic_mou_7","loc_ic_mou_8",
              "std_ic_mou_6","std_ic_mou_7","std_ic_mou_8",
              "isd_ic_mou_6","isd_ic_mou_7","isd_ic_mou_8",
              "spl_ic_mou_6","spl_ic_mou_7","spl_ic_mou_8",
              'ic_others_6','ic_others_7','ic_others_8',
              "total_ic_mou_6","total_ic_mou_7","total_ic_mou_8","Churn"
             ]

# Finding out the correlation between the features
conti_cols_corr = HV_Data[conti_cols].corr()

# Plotting the heatmap of correlation between features
plt.figure(figsize=(30,25))
sns.heatmap(conti_cols_corr, cbar=True, square= True, fmt='.2f', annot=True, annot_kws={'size':15}, cmap='Greens')
# Out:
# <AxesSubplot:>

# %%
## Correlation for Recharge

# check correlation of continuous vars with target
conti_cols = ["total_rech_num_6","total_rech_num_7","total_rech_num_8",
              "total_rech_amt_6","total_rech_amt_7","total_rech_amt_8",
              "max_rech_amt_6","max_rech_amt_7","max_rech_amt_8",
              "last_day_rch_amt_6","last_day_rch_amt_7","last_day_rch_amt_8",
              "vol_2g_mb_6","vol_2g_mb_7","vol_2g_mb_8",
              "vol_3g_mb_6","vol_3g_mb_7","vol_3g_mb_8",
              "Churn"
             ]

# Finding out the correlation between the features
conti_cols_corr = HV_Data[conti_cols].corr()

# Plotting the heatmap of correlation between features
plt.figure(figsize=(30,25))
sns.heatmap(conti_cols_corr, cbar=True, square= True, fmt='.2f', annot=True, annot_kws={'size':14}, cmap='Greens')
# Out:
# <AxesSubplot:>

# %%
## Correlation for Package

# check correlation of continuous vars with target
conti_cols = ["monthly_2g_6","monthly_2g_6","monthly_2g_6",
              "sachet_2g_6","sachet_2g_6","sachet_2g_6",
              "monthly_3g_6","monthly_3g_6","monthly_3g_6",
              "sachet_3g_6","sachet_3g_6","sachet_3g_6",
              "aon","aug_vbc_3g","jul_vbc_3g","jun_vbc_3g",
              "Churn"
             ]

# Finding out the correlation between the features
conti_cols_corr = HV_Data[conti_cols].corr()

# Plotting the heatmap of correlation between features
plt.figure(figsize=(20,15))
sns.heatmap(conti_cols_corr, cbar=True, square= True, fmt='.2f', annot=True, annot_kws={'size':14}, cmap='Greens')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Using Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=42, n_estimators=50, oob_score=True)
rf.fit(X_resampled_smt_tmk, y_resampled_smt_tmk)
# Out:
# RandomForestClassifier(n_estimators=50, oob_score=True, random_state=42)

# %%
rf.oob_score_
# Out:
# 0.9779374811538848

# %% [markdown]
# ## Hyperparamter Tuning using Randomised Search CV

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
hyper_params = {'max_depth': range(3, 20),
                'max_features': range(3, 17),
                'min_samples_leaf': range(20, 400, 50),
                'n_estimators': range(10, 101, 10)}

# %%
model_rcv = RandomizedSearchCV(estimator=rf, 
                              param_distributions=hyper_params,
                              verbose=1,
                              cv=5,
                              return_train_score=True,
                              n_jobs=-1,
                              n_iter=50)

# %%
model_rcv.fit(X_resampled_smt_tmk, y_resampled_smt_tmk)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# RandomizedSearchCV(cv=5,
#                    estimator=RandomForestClassifier(n_estimators=50,
#                                                     oob_score=True,
#                                                     random_state=42),
#                    n_iter=50, n_jobs=-1,
#                    param_distributions={'max_depth': range(3, 20),
#                                         'max_features': range(3, 17),
#                                         'min_samples_leaf': range(20, 400, 50),
#                                         'n_estimators': range(10, 101, 10)},
#                    return_train_score=True, verbose=1)

# %%
model_rcv.best_score_
# Out:
# 0.9415523654205188

# %%
rf_best = model_rcv.best_estimator_

# %%
rf_best
# Out:
# RandomForestClassifier(max_depth=15, max_features=4, min_samples_leaf=20,
#                        n_estimators=90, oob_score=True, random_state=42)

# %%
rf_best.feature_importances_
# Out:
# array([0.00000000e+00, 7.42184413e-03, 7.82426871e-03, 5.74371341e-03,
#        6.09801291e-03, 6.64603684e-03, 6.81924182e-03, 6.65170000e-03,
#        6.48406758e-03, 8.29886650e-03, 1.43880007e-02, 2.13927363e-02,
#        1.56387818e-01, 1.60584969e-02, 2.12995981e-02, 1.06291790e-01,
#        1.22250575e-02, 9.77054578e-03, 3.83674438e-02, 1.17441076e-02,
#        1.16926641e-02, 9.84332182e-03, 6.05940101e-03, 2.87000907e-03,
#        3.21363102e-03, 1.12794768e-02, 1.71995312e-02, 1.27704371e-02,
#        9.11684009e-03, 3.28455664e-07, 4.77382275e-04, 9.59837250e-03,
#        1.19624592e-02, 1.91088858e-02, 1.10644938e-02, 1.21048095e-02,
#        3.48285335e-02, 4.90196807e-03, 5.03191249e-03, 7.01729211e-03,
#        8.67910357e-03, 1.19498349e-02, 3.52024913e-02, 1.05399718e-02,
#        3.93764660e-03, 4.23001531e-03, 7.82864954e-03, 7.26558355e-03,
#        5.94893785e-03, 3.71224567e-03, 5.26564212e-03, 3.74775845e-03,
#        3.86349195e-03, 4.75621905e-03, 7.37827929e-03, 5.72063650e-03,
#        6.80201698e-03, 6.38358116e-03, 1.03089433e-02, 9.82589429e-03,
#        1.32856072e-02, 1.56768618e-02, 1.17556065e-02, 3.16129802e-02,
#        3.95113388e-03, 2.84837847e-03, 3.83421448e-03, 4.16502754e-03,
#        2.57460542e-03, 5.94184515e-03, 6.57617668e-03, 4.13254572e-03,
#        6.58009140e-03, 2.42285653e-03, 3.02514912e-03, 4.00806110e-03,
#        1.09630901e-03, 5.58947654e-04, 3.87426611e-03, 2.64599323e-04,
#        6.57746085e-04, 1.07532590e-03, 1.85050678e-02, 5.50208035e-03,
#        2.75296472e-03, 2.42921636e-03, 7.49029556e-03])

# %%
imp_df = pd.DataFrame({
    "Varname": X_resampled_smt_tmk.columns,
    "Imp": rf_best.feature_importances_
})

# %%
Var_Impact_Churn = imp_df.sort_values(by="Imp", ascending=False)[:15]

# %%
Var_Impact_Churn
# Out:
#                Varname       Imp
# 12       roam_ic_mou_8  0.156388
# 15       roam_og_mou_8  0.106292
# 18        loc_og_mou_8  0.038367
# 42      total_ic_mou_8  0.035202
# 36        loc_ic_mou_8  0.034829
# 63  last_day_rch_amt_8  0.031613
# 11       roam_ic_mou_7  0.021393
# 14       roam_og_mou_7  0.021300
# 33      total_og_mou_8  0.019109
# 82                 aon  0.018505
# 26        spl_og_mou_7  0.017200
# 13       roam_og_mou_6  0.016058
# 61  last_day_rch_amt_6  0.015677
# 10       roam_ic_mou_6  0.014388
# 60      max_rech_amt_8  0.013286

# %%
Var_Impact_Churn["Varname"].to_list()
# Out:
# ['roam_ic_mou_8',
#  'roam_og_mou_8',
#  'loc_og_mou_8',
#  'total_ic_mou_8',
#  'loc_ic_mou_8',
#  'last_day_rch_amt_8',
#  'roam_ic_mou_7',
#  'roam_og_mou_7',
#  'total_og_mou_8',
#  'aon',
#  'spl_og_mou_7',
#  'roam_og_mou_6',
#  'last_day_rch_amt_6',
#  'roam_ic_mou_6',
#  'max_rech_amt_8']

# %%
#Plot to show the feature importance
plt.figure(figsize=[8,8])
sns.barplot(x = "Varname",y="Imp",data=Var_Impact_Churn)
plt.title("Feature Importance",size=10)
plt.xticks(rotation="vertical")
plt.ylabel("Coefficient Magnitude",size=10)
plt.xlabel("Features",size=10)
plt.tick_params(size=4,labelsize = 10) # Tick size in both X and Y axes
plt.grid(0.2)

# %% [markdown]
# ## Model Evaluation

# %%
## Perfromance on Train Set
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
y_train_pred = rf_best.predict(X_resampled_smt_tmk)
accuracy_score(y_resampled_smt_tmk, y_train_pred)
# Out:
# 0.9606493114885918

# %%
## Classification report
print(classification_report(y_resampled_smt_tmk, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96     19898
#            1       0.95      0.97      0.96     19898
#
#     accuracy                           0.96     39796
#    macro avg       0.96      0.96      0.96     39796
# weighted avg       0.96      0.96      0.96     39796

# %%
## Performance on Test Set

y_test_pred = rf_best.predict(X_test)
accuracy_score(y_test, y_test_pred)
print(classification_report(y_resampled_smt_tmk, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96     19898
#            1       0.95      0.97      0.96     19898
#
#     accuracy                           0.96     39796
#    macro avg       0.96      0.96      0.96     39796
# weighted avg       0.96      0.96      0.96     39796

# %%
print(confusion_matrix(y_test,y_test_pred))
# Out:
# [[8481   52]
#  [ 258   56]]

# %% [markdown]
# ## Factor Most affecting the Churn
#
# 1. Roaming calls in the month of Aug
# 2.Local Incoming and Outgoing calls in Aug
# 3. Last recharge in Aug

# %% [markdown]
# ## To reduce the Churn of customer
#
# 1. Roaming calls to be monitored continuously and service provided
# 2. In the Action phase only customer reducing the calls to be given attractive offer on their next recharges
# 3. Last recharge amount to be compare to the last 3 months average
